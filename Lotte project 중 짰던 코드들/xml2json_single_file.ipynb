# %%
import xml.etree.ElementTree as et
#/content/drive/My Drive/0000.xml
import json
from collections import OrderedDict

# %%
xml_dir = '/content/drive/My Drive/0000.xml'
xml_file = et.parse(xml_dir)
root = xml_file.getroot()

et.dump(xml_file)
# Out:
# <annotation verified="yes">
#     <folder>Annotation</folder>
#     <filename>0000.jpg</filename>
#     <path>PascalVoc/Annotations/0000.jpg</path>
#     <source>
#         <database>Unknown</database>
#     </source>
#     <size>
#         <width>1280</width>
#         <height>960</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#     <object>
#     <name>diget_choco</name>
#     <pose>Unspecified</pose>
#     <truncated>0</truncated>
#     <difficult>0</difficult>
#     <bndbox>
#         <xmin>27.01298701298701</xmin>
#         <ymin>47.79220779220778</ymin>
#         <xmax>389.6103896103896</xmax>
#         <ymax>260.77922077922074</ymax>
#     </bndbox>
# </object><object>
#     <name>cidar</name>
#     <pose>Unspecified</pose>
#     <truncated>0</truncated>
#     <difficult>0</difficult>
#     <bndbox>
#         <xmin>449.35064935064923</xmin>
#         <ymin>28.051948051948045</ymin>
#         <xmax>848.8311688311687</xmax>
#         <ymax>194.28571428571428</ymax>
#     </bndbox>
# </object><object>
#     <name>welchs</name>
#     <pose>Unspecified</pose>
#     <truncated>0</truncated>
#     <difficult>0</difficult>
#     <bndbox>
#         <xmin>872.2077922077922</xmin>
#         <ymin>32.2077922077922</ymin>
#         <xmax>1237.9220779220777</xmax>
#         <ymax>201.55844155844156</ymax>
#     </bndbox>
# </object><object>
#     <name>homerunball</name>
#     <pose>Unspecified</pose>
#     <truncated>0</truncated>
#     <difficult>0</difficult>
#     <bndbox>
#         <xmin>58.7012987012987</xmin>
#         <ymin>259.7402597402597</ymin>
#         <xmax>572.9870129870129</xmax>
#         <ymax>531.9480519480519</ymax>
#     </bndbox>
# </object><object>
#     <name>diget_ori</name>
#     <pose>Unspecified</pose>
#     <truncated>0</truncated>
#     <difficult>0</difficult>
#     <bndbox>
#         <xmin>579.2207792207791</xmin>
#         <ymin>209.87012987012986</ymin>
#         <xmax>885.7142857142856</xmax>
#         <ymax>395.8441558441558</ymax>
#     </bndbox>
# </object><object>
#     <name>squid_peanut</name>
#     <pose>Unspecified</pose>
#     <truncated>0</truncated>
#     <difficult>0</difficult>
#     <bndbox>
#         <xmin>7.792207792207791</xmin>
#         <ymin>538.1818181818181</ymin>
#         <xmax>635.3246753246752</xmax>
#         <ymax>932.9870129870129</ymax>
#     </bndbox>
# </object><object>
#     <name>toreta</name>
#     <pose>Unspecified</pose>
#     <truncated>0</truncated>
#     <difficult>0</difficult>
#     <bndbox>
#         <xmin>554.2857142857142</xmin>
#         <ymin>408.3116883116883</ymin>
#         <xmax>773.5064935064934</xmax>
#         <ymax>630.6493506493506</ymax>
#     </bndbox>
# </object><object>
#     <name>coke</name>
#     <pose>Unspecified</pose>
#     <truncated>0</truncated>
#     <difficult>0</difficult>
#     <bndbox>
#         <xmin>880.5194805194805</xmin>
#         <ymin>390.6493506493506</ymin>
#         <xmax>1119.4805194805194</xmax>
#         <ymax>556.8831168831168</ymax>
#     </bndbox>
# </object><object>
#     <name>zec</name>
#     <pose>Unspecified</pose>
#     <truncated>0</truncated>
#     <difficult>0</difficult>
#     <bndbox>
#         <xmin>604.1558441558441</xmin>
#         <ymin>590.12987012987</ymin>
#         <xmax>1251.4285714285713</xmax>
#         <ymax>745.9740259740258</ymax>
#     </bndbox>
# </object><object>
#     <name>buttering</name>
#     <pose>Unspecified</pose>
#     <truncated>0</truncated>
#     <difficult>0</difficult>
#     <bndbox>
#         <xmin>679.9999999999999</xmin>
#         <ymin>749.090909090909</ymin>
#         <xmax>1235.8441558441557</xmax>
#         <ymax>939.2207792207791</ymax>
#     </bndbox>
# </object>
# </annotation>

# %%
json_dict = {}
current_dict = {}
relate_dict = {}
object_list = []
temp = {}
for r in root:
  if r.tag == 'object':
    for o in r:
      if o.tag == 'bndbox':
        for b in o:
          if b.text.split(' ')[0] == '\n':
            continue
          relate_dict[b.tag] = b.text
          if b.tag == 'ymax':
            current_dict[o.tag] = relate_dict
            relate_dict = {}
            object_list.append(current_dict)
            current_dict = {}
      else:
        if o.text.split(' ')[0] == '\n':
          continue
        current_dict[o.tag] = o.text
  elif r.tag == 'source' or r.tag == 'size':
    for s in r:
      if s.text.split(' ')[0] == '\n':
        continue
      json_dict[r.tag] = s.text
  else :
    json_dict[r.tag] = r.text

json_dict['object'] = object_list
print(json_dict)
# Out:
# {'folder': 'Annotation', 'filename': '0000.jpg', 'path': 'PascalVoc/Annotations/0000.jpg', 'source': 'Unknown', 'size': '3', 'segmented': '0', 'object': [{'name': 'diget_choco', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '27.01298701298701', 'ymin': '47.79220779220778', 'xmax': '389.6103896103896', 'ymax': '260.77922077922074'}}, {'name': 'cidar', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '449.35064935064923', 'ymin': '28.051948051948045', 'xmax': '848.8311688311687', 'ymax': '194.28571428571428'}}, {'name': 'welchs', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '872.2077922077922', 'ymin': '32.2077922077922', 'xmax': '1237.9220779220777', 'ymax': '201.55844155844156'}}, {'name': 'homerunball', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '58.7012987012987', 'ymin': '259.7402597402597', 'xmax': '572.9870129870129', 'ymax': '531.9480519480519'}}, {'name': 'diget_ori', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '579.2207792207791', 'ymin': '209.87012987012986', 'xmax': '885.7142857142856', 'ymax': '395.8441558441558'}}, {'name': 'squid_peanut', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '7.792207792207791', 'ymin': '538.1818181818181', 'xmax': '635.3246753246752', 'ymax': '932.9870129870129'}}, {'name': 'toreta', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '554.2857142857142', 'ymin': '408.3116883116883', 'xmax': '773.5064935064934', 'ymax': '630.6493506493506'}}, {'name': 'coke', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '880.5194805194805', 'ymin': '390.6493506493506', 'xmax': '1119.4805194805194', 'ymax': '556.8831168831168'}}, {'name': 'zec', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '604.1558441558441', 'ymin': '590.12987012987', 'xmax': '1251.4285714285713', 'ymax': '745.9740259740258'}}, {'name': 'buttering', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '679.9999999999999', 'ymin': '749.090909090909', 'xmax': '1235.8441558441557', 'ymax': '939.2207792207791'}}]}

# %%
key_list = ["folder", "filename", "path", "source", "size", "segmented", "object"]
file_data = OrderedDict()

for k in key_list:
  file_data[k] = json_dict[k]

print(json.dumps(file_data, ensure_ascii=False, indent = "\t"))

with open('/content/drive/My Drive/0000.json','w') as jf:
  json.dump(file_data,jf,ensure_ascii=False, indent="\t")
# Out:
# {
# 	"folder": "Annotation",
# 	"filename": "0000.jpg",
# 	"path": "PascalVoc/Annotations/0000.jpg",
# 	"source": "Unknown",
# 	"size": "3",
# 	"segmented": "0",
# 	"object": [
# 		{
# 			"name": "diget_choco",
# 			"pose": "Unspecified",
# 			"truncated": "0",
# 			"difficult": "0",
# 			"bndbox": {
# 				"xmin": "27.01298701298701",
# 				"ymin": "47.79220779220778",
# 				"xmax": "389.6103896103896",
# 				"ymax": "260.77922077922074"
# 			}
# 		},
# 		{
# 			"name": "cidar",
# 			"pose": "Unspecified",
# 			"truncated": "0",
# 			"difficult": "0",
# 			"bndbox": {
# 				"xmin": "449.35064935064923",
# 				"ymin": "28.051948051948045",
# 				"xmax": "848.8311688311687",
# 				"ymax": "194.28571428571428"
# 			}
# 		},
# 		{
# 			"name": "welchs",
# 			"pose": "Unspecified",
# 			"truncated": "0",
# 			"difficult": "0",
# 			"bndbox": {
# 				"xmin": "872.2077922077922",
# 				"ymin": "32.2077922077922",
# 				"xmax": "1237.9220779220777",
# 				"ymax": "201.55844155844156"
# 			}
# 		},
# 		{
# 			"name": "homerunball",
# 			"pose": "Unspecified",
# 			"truncated": "0",
# 			"difficult": "0",
# 			"bndbox": {
# 				"xmin": "58.7012987012987",
# 				"ymin": "259.7402597402597",
# 				"xmax": "572.9870129870129",
# 				"ymax": "531.9480519480519"
# 			}
# 		},
# 		{
# 			"name": "diget_ori",
# 			"pose": "Unspecified",
# 			"truncated": "0",
# 			"difficult": "0",
# 			"bndbox": {
# 				"xmin": "579.2207792207791",
# 				"ymin": "209.87012987012986",
# 				"xmax": "885.7142857142856",
# 				"ymax": "395.8441558441558"
# 			}
# 		},
# 		{
# 			"name": "squid_peanut",
# 			"pose": "Unspecified",
# 			"truncated": "0",
# 			"difficult": "0",
# 			"bndbox": {
# 				"xmin": "7.792207792207791",
# 				"ymin": "538.1818181818181",
# 				"xmax": "635.3246753246752",
# 				"ymax": "932.9870129870129"
# 			}
# 		},
# 		{
# 			"name": "toreta",
# 			"pose": "Unspecified",
# 			"truncated": "0",
# 			"difficult": "0",
# 			"bndbox": {
# 				"xmin": "554.2857142857142",
# 				"ymin": "408.3116883116883",
# 				"xmax": "773.5064935064934",
# 				"ymax": "630.6493506493506"
# 			}
# 		},
# 		{
# 			"name": "coke",
# 			"pose": "Unspecified",
# 			"truncated": "0",
# 			"difficult": "0",
# 			"bndbox": {
# 				"xmin": "880.5194805194805",
# 				"ymin": "390.6493506493506",
# 				"xmax": "1119.4805194805194",
# 				"ymax": "556.8831168831168"
# 			}
# 		},
# 		{
# 			"name": "zec",
# 			"pose": "Unspecified",
# 			"truncated": "0",
# 			"difficult": "0",
# 			"bndbox": {
# 				"xmin": "604.1558441558441",
# 				"ymin": "590.12987012987",
# 				"xmax": "1251.4285714285713",
# 				"ymax": "745.9740259740258"
# 			}
# 		},
# 		{
# 			"name": "buttering",
# 			"pose": "Unspecified",
# 			"truncated": "0",
# 			"difficult": "0",
# 			"bndbox": {
# 				"xmin": "679.9999999999999",
# 				"ymin": "749.090909090909",
# 				"xmax": "1235.8441558441557",
# 				"ymax": "939.2207792207791"
# 			}
# 		}
# 	]
# }
